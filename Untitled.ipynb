# %%
Plot[Sin[x], {x, 0, 2 Pi}]
# Out:
# -Graphics-

# %%
ListPlot[Table[{n, Prime[n]}, {n, 1, 50}], Joined -> True]
# Out:
# -Graphics-

# %%
Plot3D[Sin[x] Cos[y], {x, 0, 2Pi}, {y, 0, 2Pi}]
# Out:
# -Graphics3D-

# %%
Image[RandomReal[{0,1}, {100, 100}]]
# Out:
# -Image-

# %%
Solve[x^2 - 5 x + 6 == 0, x]
# Out:
# {{x -> 2}, {x -> 3}}

# %%
(* 两个表达式在同一 cell — 测试多结果 MIME 合并 *)
1 + 1
Plot[x^2, {x, -3, 3}]
# Out:
# 2
# -Graphics-
